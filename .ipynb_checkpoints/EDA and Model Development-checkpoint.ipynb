# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
sns.set(style='darkgrid', palette='terrain')

# %%
engine = create_engine('sqlite:///merged.db')
merged = pd.read_sql_table("merged", con=engine)
merged.head()
# Out:
#     offer_id                             lead_uuid     apr  lender_id  \
# 0  810117850  ae2d5046-a7c7-44fe-b6f4-cde3d8bf29e2  199.00       1103
# 1  810119030  b12fbb06-1402-4de3-a91f-fb6360ff85e4  249.00       1103
# 2  810122970  a119a3db-ab14-46fc-acd1-35cf20dec1ec  249.00       1103
# 3  810124218  3166d6bd-1c79-44c0-867c-889afd35990c   17.69        240
# 4  810124220  3166d6bd-1c79-44c0-867c-889afd35990c   17.19        240
#
#    requested        loan_purpose credit  annual_income clicked_at
# 0      500.0  debt_consolidation   fair        72000.0        NaT
# 1      500.0  debt_consolidation   poor        29724.0        NaT
# 2      500.0  debt_consolidation   poor        60000.0        NaT
# 3    50000.0  debt_consolidation   good       139000.0        NaT
# 4    50000.0  debt_consolidation   good       139000.0        NaT

# %% [markdown]
# # Check Data Quality

# %%
merged.isnull().sum()
# Out:
# offer_id              0
# lead_uuid             0
# apr                  17
# lender_id             0
# requested           281
# loan_purpose          0
# credit                0
# annual_income       130
# clicked_at       449619
# dtype: int64

# %%
merged.duplicated().sum()
# Out:
# 0

# %%
merged[merged['annual_income'].isnull() == True]
# Out:
#          offer_id                             lead_uuid     apr  lender_id  \
# 15179   810176031  0c1b4ff4-d657-48f4-b7cd-500b5a01cc21   10.00        473
# 17167   810387917  ec7f0492-7d43-4ca6-b5ca-f858c8e27078   10.00        473
# 22967   810180396  818b7842-caeb-49cd-a153-f22bf82dcb41    9.74        417
# 22968   810180393  818b7842-caeb-49cd-a153-f22bf82dcb41    6.99        641
# 22969   810180391  818b7842-caeb-49cd-a153-f22bf82dcb41   11.69        939
# ...           ...                                   ...     ...        ...
# 451742  812889351  898a999c-2af9-4ac2-bfe1-3feb7c01fa7b  100.00        262
# 451743  812889352  898a999c-2af9-4ac2-bfe1-3feb7c01fa7b   17.95        386
# 453717  813042983  c05afc40-0065-4696-9405-254f51e62cf6   10.00        473
# 454083  813068974  9d5c2305-b336-4dd8-b050-36715bd009b5   10.00        473
# 456730  813057538  204b3f4a-e636-4f16-9e1c-6432a59bc79b   10.00        473
#
# ...

# %%
merged['lead_uuid'].iloc[1]
# Out:
# 'b12fbb06-1402-4de3-a91f-fb6360ff85e4'

# %%
merged[merged['lead_uuid']=='b12fbb06-1402-4de3-a91f-fb6360ff85e4']
# Out:
#     offer_id                             lead_uuid    apr  lender_id  \
# 1  810119030  b12fbb06-1402-4de3-a91f-fb6360ff85e4  249.0       1103
#
#    requested        loan_purpose credit  annual_income clicked_at
# 1      500.0  debt_consolidation   poor        29724.0        NaT

# %%
merged['credit'].value_counts()
# Out:
# poor         170610
# good         129705
# fair         109994
# excellent     47876
# None            407
# limited         300
# unknown          47
# Name: credit, dtype: int64

# %%
merged['clicked_at'] = merged['clicked_at'].fillna(0)

# %%
merged.head()
# Out:
#     offer_id                             lead_uuid     apr  lender_id  \
# 0  810117850  ae2d5046-a7c7-44fe-b6f4-cde3d8bf29e2  199.00       1103
# 1  810119030  b12fbb06-1402-4de3-a91f-fb6360ff85e4  249.00       1103
# 2  810122970  a119a3db-ab14-46fc-acd1-35cf20dec1ec  249.00       1103
# 3  810124218  3166d6bd-1c79-44c0-867c-889afd35990c   17.69        240
# 4  810124220  3166d6bd-1c79-44c0-867c-889afd35990c   17.19        240
#
#    requested        loan_purpose credit  annual_income clicked_at
# 0      500.0  debt_consolidation   fair        72000.0          0
# 1      500.0  debt_consolidation   poor        29724.0          0
# 2      500.0  debt_consolidation   poor        60000.0          0
# 3    50000.0  debt_consolidation   good       139000.0          0
# 4    50000.0  debt_consolidation   good       139000.0          0

# %%
merged['clicked_offer'] = merged['clicked_at'].apply(lambda x: 0 if x==0 else 1)

# %%
merged['clicked_offer'].value_counts()
# Out:
# 0    449619
# 1      9320
# Name: clicked_offer, dtype: int64

# %%
len(merged)
# Out:
# 458939

# %%
merged['offer_id'].nunique()
# Out:
# 458939

# %%
merged['lead_uuid'].nunique()
# Out:
# 100000

# %%
merged['lender_id'].nunique()
# Out:
# 26

# %% [markdown]
# # Remove Missing Data

# %%
merged = merged.dropna()

# %%
merged.isnull().sum()
# Out:
# offer_id         0
# lead_uuid        0
# apr              0
# lender_id        0
# requested        0
# loan_purpose     0
# credit           0
# annual_income    0
# clicked_at       0
# clicked_offer    0
# dtype: int64

# %% [markdown]
# # Summary Statistics

# %%
merged.describe()
# Out:
#            offer_id            apr      lender_id      requested  \
# count  4.585690e+05  458569.000000  458569.000000  458569.000000
# mean   8.116343e+08      96.000669    1044.109235    7132.598553
# std    8.574052e+05      80.802998     690.815594   12813.218213
# min    8.101167e+08       0.188400     237.000000       1.000000
# 25%    8.108888e+08      23.710000     363.000000    1000.000000
# 50%    8.116595e+08      98.023000    1103.000000    1500.000000
# 75%    8.123836e+08     149.000000    1777.000000    8000.000000
# max    8.130695e+08     643.932000    2139.000000  250000.000000
#
#        annual_income  clicked_offer
# count   4.585690e+05  458569.000000
# mean    6.552825e+04       0.020315
# std     6.970830e+04       0.141077
# min     0.000000e+00       0.000000
# 25%     3.600000e+04       0.000000
# 50%     5.400000e+04       0.000000
# 75%     7.300000e+04       0.000000
# max     1.111111e+07       1.000000

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458569 entries, 0 to 458938
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   offer_id       458569 non-null  int64
#  1   lead_uuid      458569 non-null  object
#  2   apr            458569 non-null  float64
#  3   lender_id      458569 non-null  int64
#  4   requested      458569 non-null  float64
#  5   loan_purpose   458569 non-null  object
#  6   credit         458569 non-null  object
#  7   annual_income  458569 non-null  float64
#  8   clicked_at     458569 non-null  object
#  9   clicked_offer  458569 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 38.5+ MB

# %%
features = merged[['apr', 'lender_id', 'requested',
                'loan_purpose', 'credit', 'annual_income']]

target = merged['clicked_offer']

# %%
rus = RandomUnderSampler(
    sampling_strategy="auto",  # majority class will be twice as many as minority class
    random_state=0,  # for reproducibility
    replacement=True # if it should resample with replacement
)  

features, target= rus.fit_resample(features, target)

# %%
merged = pd.concat([features, target], axis=1)

# %%
merged['clicked_offer'].value_counts()
# Out:
# 0    9316
# 1    9316
# Name: clicked_offer, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
def plot_box_dist(df, col):
    ''' 
    Makes s boxplot and a distribution plot side by side.
    
    Args:
    
    df(dataframe): pandas dataframe
    col(str): column name
    
    '''
    # Set figsize
    plt.figure(figsize = (14, 6))
    
    # Create the first plot
    plt.subplot(1,2,1)
    sns.boxplot(df[col], orient='v')
    
    # Create the second plot
    plt.subplot(1,2,2)
    sns.distplot(df[col], bins=20)

# %%
plot_box_dist(merged, 'apr')

# %%
plot_box_dist(merged, 'requested')

# %%
plot_box_dist(merged, 'annual_income')

# %%
def plot_value_counts(df, col):
    plt.figure(figsize=(20,8))
    value_counts = df[col].value_counts()
    sns.barplot(value_counts.index, value_counts.values, palette='terrain', alpha=0.6)
    plt.xticks(rotation=45)

# %%
plot_value_counts(merged, 'loan_purpose')

# %%
plot_value_counts(merged, 'credit')

# %%
plot_value_counts(merged, 'clicked_offer')

# %%
merged['clicked_offer'].value_counts(normalize=True)
# Out:
# 0    0.5
# 1    0.5
# Name: clicked_offer, dtype: float64

# %%
def create_two_kdeplots(df, target_variable, col):
    ''' 
    Makes two kdeplots stacked on one another.
    
    Args:
    
    df(dataframe): pandas dataframe
    col(str): column name
    
    '''
    plt.figure(figsize=(12,7))

    sns.kdeplot(df[df[target_variable]==0][col], 
                label = 'Unclicked Offers', 
                shade = True)
    
    sns.kdeplot(df[df[target_variable]==1][col], 
                label = "Clicked Offers", 
                shade = True)

    plt.xlabel(col)

# %%
create_two_kdeplots(merged, 'clicked_offer',  'apr')

# %%
create_two_kdeplots(merged, 'clicked_offer',  'requested')

# %%
create_two_kdeplots(merged, 'clicked_offer',  'annual_income')

# %%
def plot_target_hue(df, col):
    plt.figure(figsize=(20,9))
    sns.countplot(x=col, hue='clicked_offer', 
                  data=df, alpha=0.8)
    plt.xticks(rotation=45)

# %%
plot_target_hue(merged, 'loan_purpose')

# %%
plot_target_hue(merged, 'credit')

# %%
plot_target_hue(merged, 'lender_id')

# %%
merged.columns
# Out:
# Index(['apr', 'lender_id', 'requested', 'loan_purpose', 'credit',
#        'annual_income', 'clicked_offer'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
matrix = merged.corr()
sns.heatmap(matrix, cbar=False, annot=True, fmt='.2g', cmap='Blues')

# %% [markdown]
# # Create Baseline Model

# %%
x_train, x_test, y_train, y_test = train_test_split(features, target,
                                                    test_size=0.3,
                                                    shuffle=True,
                                                    stratify=merged['clicked_offer'],
                                                    random_state=42)

# %%
x_train.shape, y_train.shape
# Out:
# ((13042, 6), (13042,))

# %%
x_test.shape, y_test.shape
# Out:
# ((5590, 6), (5590,))

# %%
columns = features.columns
columns
# Out:
# Index(['apr', 'lender_id', 'requested', 'loan_purpose', 'credit',
#        'annual_income'],
#       dtype='object')

# %% [markdown]
# We are going to use a naive approach to create a baseline model.
# Since the majority class is "0", we are going to predict all the  as 0.

# %%
base_pred = [0 for i in range(len(y_test))]

# %%
len(base_pred)
# Out:
# 5590

# %%
def plot_score(y_true, predictions):
    print('Accuracy score is:')
    print(round(accuracy_score(y_true, predictions), 3))
    print('F1 score is:')
    print(round(f1_score(y_true, predictions), 3))

# %%
plot_score(y_test, base_pred)
# Out:
# Accuracy score is:
# 0.5
# F1 score is:
# 0.0

# %%
# rus = RandomUnderSampler(
#     sampling_strategy="auto",  # majority class will be twice as many as minority class
#     random_state=0,  # for reproducibility
#     replacement=True # if it should resample with replacement
# )  

# x_train, y_train = rus.fit_resample(x_train, y_train)

# %%
def get_scores(true_labels, predictions):
    """
    Print accuracy score and AUC score.
    
    Args:
    true_labels: an array or a list of ground truth labels
    predictions: an array or a list of predicted labels
    
    """
    acc_score = accuracy_score(true_labels, predictions)
    auc_score = roc_auc_score(true_labels, predictions)
    fpr, tpr, thresholds = roc_curve(true_labels, predictions)
    print(f'Accuracy score is {acc_score}')
    print(f'AUC score is {auc_score}')

# %%
# using naive approach to predict every entry as 1 (the majority calss)
ns_predictions = [0 for _ in range(len(x_test))]
# find false positive rate and true positive rate using sklearn's roc_curve
ns_fpr, ns_tpr, thresholds = roc_curve(y_test, ns_predictions)

# %%
get_scores(y_test, ns_predictions)
# Out:
# Accuracy score is 0.5
# AUC score is 0.5

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Group Rare Labels

# %%
# def group_rare_labels(df, col):
#     ''' 
#     Create a dictionary to replace the rare labels with the
#     string 'rare' if they are present in less than 5% 
    
#     Args:
    
#     df(dataframe): pandas dataframe
#     col(str): column name
    
#     '''

#     total_counts = len(df)

#     # first I calculate the % of the labels for each category
#     temp_df = pd.Series(df[col].value_counts() / total_counts)

#     # now I create a dictionary to replace the rare labels with the
#     # string 'rare' if they are present in less than 5% 

#     grouping_dict = {
#         k: ('rare' if k not in temp_df[temp_df >= 0.05].index else k)
#         for k in temp_df.index
#     }

#     # now I replace the rare categories
#     tmp = df[col].map(grouping_dict)

#     return tmp

# %%
x_test.isnull().sum()
# Out:
# apr              0
# lender_id        0
# requested        0
# loan_purpose     0
# credit           0
# annual_income    0
# dtype: int64

# %% [markdown]
# ### Target Mean Encoding for Categorical Variables

# %%
def frequency_labels(df, col):
    
    labels = df[col].value_counts().to_dict()

    return labels

# %%
for col in x_train.select_dtypes('object').columns:
    labels = frequency_labels(x_train, col)
    x_train[col] = x_train[col].map(labels)
    x_test[col] = x_test[col].map(labels)
# Out:
# <ipython-input-63-cd2cfa7f0e92>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train[col] = x_train[col].map(labels)
# <ipython-input-63-cd2cfa7f0e92>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test[col] = x_test[col].map(labels)

# %%
### Get Rid of Outliers

# %%
def find_boundaries(df, col):
    
    """ Identify outliers by using IQR rule
    
    Args:
    
    df(dataframe): pandas dataframe
    col(str): column name
    
    Return:
    lower_boundary: lower boundary of the outliers as a float number
    upper_boundary: upper boundary of the outliers as a float number
    
    """

    IQR = df[col].quantile(0.75) - df[col].quantile(0.25)

    lower_boundary = df[col].quantile(0.25) - (IQR * 1.5)
    upper_boundary = df[col].quantile(0.75) + (IQR * 1.5)

    return upper_boundary, lower_boundary

# %%
apr_upper, apr_lower = find_boundaries(merged, 'apr')

print(apr_upper, apr_lower)
# Out:
# 339.455 -168.42499999999998

# %%
merged['apr']= np.where(merged['apr'] > apr_upper, apr_upper,
                       np.where(merged['apr'] < apr_lower, apr_lower, merged['apr']))

# %%
requested_upper, requested_lower = find_boundaries(merged, 'requested')

print(requested_upper, requested_lower)
# Out:
# 23500.0 -12500.0

# %%
merged['requested']= np.where(merged['requested'] > requested_upper, requested_upper,
                       np.where(merged['requested'] < requested_lower, requested_lower, merged['requested']))

# %%
income_upper, income_lower = find_boundaries(merged, 'annual_income')

print(income_upper, income_lower)
# Out:
# 141000.0 -27000.0

# %%
merged['annual_income']= np.where(merged['annual_income'] > income_upper, income_upper,
                       np.where(merged['annual_income'] < income_lower, income_lower, merged['annual_income']))

# %%
merged = merged.reset_index()

# %% [markdown]
# ### Data Scaling

# %%
scaler = RobustScaler()
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
x_train = pd.DataFrame(x_train, columns=columns)
x_train.head()
# Out:
#         apr  lender_id  requested  loan_purpose    credit  annual_income
# 0  1.694823   0.473103  -0.477778      0.000000  0.622596      -0.595238
# 1  1.395398   0.473103  -0.500000     -1.073472  0.622596      -0.928571
# 2  1.395398   0.473103  -0.500000      0.000000  0.622596      -0.119048
# 3 -0.202269   0.360000   3.888889      0.000000 -1.943910       1.190476
# 4  0.906863   0.937931  -0.444444      0.000000  0.622596      -0.880952

# %%
x_test = pd.DataFrame(x_test, columns=columns)
x_test.head()
# Out:
#         apr  lender_id  requested  loan_purpose    credit  annual_income
# 0 -0.184540   0.154483   0.500000     -1.000000 -1.943910       2.023810
# 1  1.395398   0.473103  -0.500000      0.000000  0.622596      -0.547619
# 2 -0.110470  -0.124138   1.111111     -1.000000  0.000000      -0.214286
# 3 -0.178473   0.140690   0.222222     -1.000000 -1.943910       1.771524
# 4  0.906863   0.937931  -0.333333     -1.085972  0.000000      -0.452381

# %%
test_data = pd.concat([x_test, y_test], axis=1)
test_data = test_data.dropna()

# %%
x_test = test_data.drop(columns=['clicked_offer'])
y_test = test_data['clicked_offer']

# %%
x_test.head()
# Out:
#         apr  lender_id  requested  loan_purpose    credit  annual_income
# 1  1.395398   0.473103  -0.500000      0.000000  0.622596      -0.547619
# 2 -0.110470  -0.124138   1.111111     -1.000000  0.000000      -0.214286
# 4  0.906863   0.937931  -0.333333     -1.085972  0.000000      -0.452381
# 5 -0.114333   0.027586  21.666667     -1.013056 -1.943910       0.714286
# 9  0.906863   0.937931  -0.388889     -0.922917  0.622596      -0.780952

# %% [markdown]
# ### Feature Engineering

# %%
def add_group_stats(df, target_col, cat_col):  
    groups = df.groupby(cat_col)
    group_stats_df = pd.DataFrame({'group_mean': groups[target_col].mean()})
    group_stats_df['group_max'] = groups[target_col].max()
    group_stats_df['group_min'] = groups[target_col].min()
    group_stats_df['group_std'] = groups[target_col].std()
    group_stats_df['group_median'] = groups[target_col].median()
    group_stats_df.columns = [cat_col + 'group_mean', cat_col + 'group_max', 
                              cat_col + 'group_min', cat_col +'group_std', 
                              cat_col +'group_median']
    df = pd.concat()

# %%
plt.figure(figsize=(12, 7))
scaled_matrix = pd.concat([x_train, y_train], axis=1).corr()
sns.heatmap(scaled_matrix, cbar=False, annot=True, fmt='.2g', cmap='Blues')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

# %%
def select_model(train_X, train_y):

    # List of dictionaries, each containing a model name,
    # it's estimator and a dict of hyperparameters
    models = [
        {
            "name": "KNeighborsClassifier",
            "estimator": KNeighborsClassifier(),
            "hyperparameters":
                {
                    "n_neighbors": range(1,20,2),
                    "weights": ["distance", "uniform"],
                    "p": [1,2]
                }
        },
        {
            "name": "RandomForestClassifier",
            "estimator": RandomForestClassifier(random_state=42),
            "hyperparameters":
                {
                    "n_estimators": [100],
                    "max_depth": [2, 5, 10],
                    "max_features": ["log2", "sqrt"],
                    "min_samples_leaf": [1, 5, 8],
                    "min_samples_split": [2, 3, 5]

                }
        },
        {
            "name": "Gradient Boosting Classifier",
            "estimator": GradientBoostingClassifier(random_state=42),
            "hyperparameters":
                {
                    "learning_rate": [0.01, 0.1, 0.2],
                    "min_samples_split": [2, 3, 5],
                    "min_samples_leaf": [1, 5, 8],
                    "max_depth":[3,5,8],
                    "max_features":["log2","sqrt"],
                    "subsample":[0.6, 0.8],
                }
        }
    ]

    for model in models:
        print(model['name'])
        print('-'*len(model['name']))
        grid = GridSearchCV(model["estimator"],
                            param_grid=model["hyperparameters"],
                            scoring='roc_auc',
                            n_jobs=-1,
                            cv=3)
        grid.fit(train_X, train_y)
        model["best_params"] = grid.best_params_
        model["best_score"] = grid.best_score_
        model["best_model"] = grid.best_estimator_

        print("Best Score: {}".format(model["best_score"]))
        print("Best Parameters: {}".format(model["best_params"]))
        print("Best Estimator: {}".format(model['best_model']))

    return models

# %%
select_model(x_train, y_train)
# Out:
# KNeighborsClassifier
# --------------------
# Best Score: 0.7977599643196275
# Best Parameters: {'n_neighbors': 19, 'p': 1, 'weights': 'uniform'}
# Best Estimator: KNeighborsClassifier(n_neighbors=19, p=1)
# RandomForestClassifier
# ----------------------
# Best Score: 0.8367049924629487
# Best Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100}
# Best Estimator: RandomForestClassifier(max_depth=10, max_features='log2', min_samples_leaf=5,
#                        random_state=42)
# Gradient Boosting Classifier
# ----------------------------
# Best Score: 0.8367794370697706
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 8, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'subsample': 0.8}
# Best Estimator: GradientBoostingClassifier(max_depth=8, max_features='log2', min_samples_leaf=8,
#                            random_state=42, subsample=0.8)
# [{'name': 'KNeighborsClassifier',
# ...

# %%
knn_model = KNeighborsClassifier(n_neighbors=19, p=1, weights='distance')

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=19, p=1, weights='distance')

# %%
knn_preds = knn_model.predict(x_test)

# %%
get_scores(y_test, knn_preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-ebb73bb49105> in <module>
# ----> 1 get_scores(y_test, knn_preds)
#
# <ipython-input-53-bb7bbdc1dd77> in get_scores(true_labels, predictions)
#       9     """
#      10     acc_score = accuracy_score(true_labels, predictions)
# ---> 11     auc_score = roc_auc_score(true_labels, predictions)
#      12     fpr, tpr, thresholds = roc_curve(true_labels, predictions)
#      13     print(f'Accuracy score is {acc_score}')
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %%
rfc_model = RandomForestClassifier(max_depth=10, max_features='log2', random_state=42)

# %%
rfc_model.fit(x_train, y_train)

# %%
rfc_preds = rfc_model.predict(x_test)

# %%
get_scores(y_test, rfc_preds)

# %%
gbc_model = GradientBoostingClassifier(learning_rate=0.2, max_depth=8, max_features='log2',
                                       random_state=42, subsample=0.8)

# %%
gbc_model.fit(x_train, y_train)

# %%
gbc_preds = gbc_model.predict(x_test)

# %%
get_scores(y_test, gbc_preds)

# %%
# build a list of prediction
pred_list = [knn_preds, rfc_preds, gbc_preds]
# build a list of model names
model_list = ['KNN', 'Random Forest', 'Gradient Boosting']

# %%
def plot_roc_curve(true_labels, pred_list, model_list):
    
    """
    Plot ROC curve.
    
    Args:
    true_labels: an array or a list of ground truth labels
    pred_list: a list of predicted labels from different models
    model_list: a list of model names
    
    """
    plt.figure(figsize=(16,12))
    # plot the roc curve for the model
    plt.plot(ns_fpr, ns_tpr, linestyle='--', label='Naive Approach')
    
    for i in range(len(model_list)):
        fpr, tpr, _ = roc_curve(true_labels, pred_list[i])
        plt.plot(fpr, tpr, marker='.', label=model_list[i])
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    # show the legend
    plt.legend()

# %%
plot_roc_curve(y_test, pred_list, model_list)

# %%
# Save Model Using Pickle
import pickle

# save the model to disk
filename_1 = 'gbc_model.sav'
pickle.dump(gbc_model, open(filename_1, 'wb'))
